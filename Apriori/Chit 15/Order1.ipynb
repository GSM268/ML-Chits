# %%
import numpy as np
import pandas as pd

# !pip install apyori
from apyori import apriori
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
df=pd.read_csv("Order1.csv")

# %%
df
# Out:
#        Member_number        Date        itemDescription
# 0               1808  21-07-2015         tropical fruit
# 1               2552  05-01-2015             whole milk
# 2               2300  19-09-2015              pip fruit
# 3               1187  12-12-2015       other vegetables
# 4               3037  01-02-2015             whole milk
# ...              ...         ...                    ...
# 38760           4471  08-10-2014          sliced cheese
# 38761           2022  23-02-2014                  candy
# 38762           1097  16-04-2014               cake bar
# 38763           1510  03-12-2014  fruit/vegetable juice
# 38764           1521  26-12-2014               cat food
#
# [38765 rows x 3 columns]

# %%
groups=df.groupby(by="Member_number")

# %%
records=groups.apply(lambda x:[x.iloc[i,2] for i in range(len(x))])
records
# Out:
# Member_number
# 1000    [soda, canned beer, sausage, sausage, whole mi...
# 1001    [frankfurter, frankfurter, beef, sausage, whol...
# 1002    [tropical fruit, butter milk, butter, frozen v...
# 1003    [sausage, root vegetables, rolls/buns, deterge...
# 1004    [other vegetables, pip fruit, root vegetables,...
#                               ...
# 4996    [dessert, salty snack, rolls/buns, misc. bever...
# 4997    [tropical fruit, white wine, whole milk, curd,...
# 4998                                   [rolls/buns, curd]
# 4999    [bottled water, butter milk, tropical fruit, b...
# 5000    [soda, bottled beer, fruit/vegetable juice, ro...
# Length: 3898, dtype: object

# %%
association_rules=apriori(records,min_support=0.003,min_confidence=0.3,min_lift=3)
association_result=list(association_rules)

# %%
print(association_result[0])
# Out:
# RelationRecord(items=frozenset({'domestic eggs', 'meat spreads'}), support=0.0035915854284248334, ordered_statistics=[OrderedStatistic(items_base=frozenset({'meat spreads'}), items_add=frozenset({'domestic eggs'}), confidence=0.4, lift=3.0042389210019267)])

# %%
for i in association_result:
  pair =i[0]
  item=[x for x in pair]

  print("Rules:"+item[0]+"---->"+item[1])
  print("Support"+str(i[1]))
  print("Confidence"+str(i[2][0][2]))
  print("Lift"+str(i[2][0][3]))
# Out:
# Rules:domestic eggs---->meat spreads
# Support0.0035915854284248334
# Confidence0.4
# Lift3.0042389210019267
# Rules:baking powder---->bottled water
# Support0.0030785017957927143
# Confidence0.31578947368421056
# Lift3.6526628143057946
# Rules:coffee---->butter
# Support0.0033350436121087736
# Confidence0.39393939393939387
# Lift3.1147581289569115
# Rules:waffles---->chicken
# Support0.0030785017957927143
# Confidence0.35294117647058826
# Lift3.509603841536615
# Rules:whipped/sour cream---->sausage
# Support0.0030785017957927143
# Confidence0.75
# Lift3.6407222914072226
# Rules:cream cheese ---->tropical fruit
# Support0.0030785017957927143
# Confidence0.32432432432432434
# Lift3.6643948296122213
# Rules:dessert---->red/blush wine
# Support0.0035915854284248334
# Confidence0.6666666666666666
# Lift3.7552986512524082
# Rules:newspapers---->sausage
# Support0.0035915854284248334
# Confidence0.4242424242424242
# Lift3.0343063664164576
# Rules:domestic eggs---->meat spreads
# ...
